# %% [markdown]
# # MSDS 400 Homework Assignment 5

# %% [markdown]
# ### Question 1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (11, 11))
question_1 = plt.imread('Homework_Assignment_5_Question_1.jpg')
plt.imshow(question_1)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 2

# %%
plt.figure(figsize = (11, 11))
question_2 = plt.imread('Homework_Assignment_5_Question_2.jpg')
plt.imshow(question_2)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 3

# %%
plt.figure(figsize = (11, 11))
question_3 = plt.imread('Homework_Assignment_5_Question_3.jpg')
plt.imshow(question_3)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 4

# %%
plt.figure(figsize = (11, 11))
question_4 = plt.imread('Homework_Assignment_5_Question_4.jpg')
plt.imshow(question_4)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 5

# %%
plt.figure(figsize = (11, 11))
question_5 = plt.imread('Homework_Assignment_5_Question_5.jpg')
plt.imshow(question_5)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 6

# %%
plt.figure(figsize = (11, 11))
question_6 = plt.imread('Homework_Assignment_5_Question_6.jpg')
plt.imshow(question_6)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 7

# %%
plt.figure(figsize = (13, 13))
question_7 = plt.imread('Homework_Assignment_5_Question_7.jpg')
plt.imshow(question_7)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 8

# %%
plt.figure(figsize = (13, 13))
question_8 = plt.imread('Homework_Assignment_5_Question_8.jpg')
plt.imshow(question_8)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 9

# %%
plt.figure(figsize = (13, 13))
question_9 = plt.imread('Homework_Assignment_5_Question_9.jpg')
plt.imshow(question_9)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 10

# %%
plt.figure(figsize = (13, 13))
question_10 = plt.imread('Homework_Assignment_5_Question_10.jpg')
plt.imshow(question_10)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 11

# %%
plt.figure(figsize = (13, 13))
question_11 = plt.imread('Homework_Assignment_5_Question_11.jpg')
plt.imshow(question_11)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 12

# %%
plt.figure(figsize = (13, 13))
question_12 = plt.imread('Homework_Assignment_5_Question_12.jpg')
plt.imshow(question_12)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 13

# %%
plt.figure(figsize = (13, 13))
question_13 = plt.imread('Homework_Assignment_5_Question_13.jpg')
plt.imshow(question_13)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 14

# %%
plt.figure(figsize = (13, 13))
question_14 = plt.imread('Homework_Assignment_5_Question_14.jpg')
plt.imshow(question_14)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Question 15

# %%
plt.figure(figsize = (13, 13))
question_15 = plt.imread('Homework_Assignment_5_Question_15.jpg')
plt.imshow(question_15)
plt.axis("off")
plt.show()
